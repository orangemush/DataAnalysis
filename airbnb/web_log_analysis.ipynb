# %%
import pandas as pd
import seaborn as sns
from os.path import join

# 링크
print("https://www.kaggle.com/c/airbnb-recruiting-new-user-bookings/data")
# Out:
# https://www.kaggle.com/c/airbnb-recruiting-new-user-bookings/data

# %%
train_path     = join("data", "train_users_2.csv")
sessions_path  = join("data", "sessions.csv")
age_path       = join("data", "age_gender_bkts.csv")
countries_path = join("data", "countries.csv")

# test_path      = join("data", "test_users.csv")

# %%
account_df = pd.read_csv(train_path)
age_df     = pd.read_csv(age_path)
country_df = pd.read_csv(countries_path)
session_df = pd.read_csv(sessions_path)

# %% [markdown]
# - account_df는 유저의 계정 정보를 담고 있습니다.
# - age_df는

# %%
print(account_df.shape)
account_df.head(3)
# Out:
# (213451, 16)
#            id date_account_created  timestamp_first_active date_first_booking  \
# 0  gxn3p5htnn           2010-06-28          20090319043255                NaN
# 1  820tgsjxq7           2011-05-25          20090523174809                NaN
# 2  4ft3gnwmtx           2010-09-28          20090609231247         2010-08-02
#
#       gender   age signup_method  signup_flow language affiliate_channel  \
# 0  -unknown-   NaN      facebook            0       en            direct
# 1       MALE  38.0      facebook            0       en               seo
# 2     FEMALE  56.0         basic            3       en            direct
#
#   affiliate_provider first_affiliate_tracked signup_app first_device_type  \
# 0             direct               untracked        Web       Mac Desktop
# 1             google               untracked        Web       Mac Desktop
# 2             direct               untracked        Web   Windows Desktop
#
#   first_browser country_destination
# ...

# %%
account_df.isnull().sum()
# Out:
# id                              0
# date_account_created            0
# timestamp_first_active          0
# date_first_booking         124543
# gender                          0
# age                         87990
# signup_method                   0
# signup_flow                     0
# language                        0
# affiliate_channel               0
# affiliate_provider              0
# first_affiliate_tracked      6065
# signup_app                      0
# first_device_type               0
# first_browser                   0
# country_destination             0
# dtype: int64

# %%
account_df["gender"].value_counts()
# Out:
# -unknown-    95688
# FEMALE       63041
# MALE         54440
# OTHER          282
# Name: gender, dtype: int64

# %%
account_df["first_affiliate_tracked"].value_counts()
# Out:
# untracked        109232
# linked            46287
# omg               43982
# tracked-other      6156
# product            1556
# marketing           139
# local ops            34
# Name: first_affiliate_tracked, dtype: int64

# %%
print(session_df.shape)
session_df.head(3)
# Out:
# (10567737, 6)
#       user_id          action action_type        action_detail  \
# 0  d1mm9tcy42          lookup         NaN                  NaN
# 1  d1mm9tcy42  search_results       click  view_search_results
# 2  d1mm9tcy42          lookup         NaN                  NaN
#
#        device_type  secs_elapsed
# 0  Windows Desktop         319.0
# 1  Windows Desktop       67753.0
# 2  Windows Desktop         301.0

# %%
session_df["user_id"].value_counts()
# Out:
# mxqbh3ykxl    2722
# 0hjoc5q8nf    2644
# mjbl6rrj52    2476
# l5lgm3w5pc    2424
# wg9413iaux    2362
#               ...
# 28ducycdim       1
# g09kkvjc6h       1
# n02i24pakw       1
# ac2u4y37a4       1
# zdb1vza42c       1
# Name: user_id, Length: 135483, dtype: int64

# %%
print(age_df.shape)
age_df.head(3)
# Out:
# (420, 5)
#   age_bucket country_destination gender  population_in_thousands    year
# 0       100+                  AU   male                      1.0  2015.0
# 1      95-99                  AU   male                      9.0  2015.0
# 2      90-94                  AU   male                     47.0  2015.0

# %%
age_df
# Out:
#     age_bucket country_destination  gender  population_in_thousands    year
# 0         100+                  AU    male                      1.0  2015.0
# 1        95-99                  AU    male                      9.0  2015.0
# 2        90-94                  AU    male                     47.0  2015.0
# 3        85-89                  AU    male                    118.0  2015.0
# 4        80-84                  AU    male                    199.0  2015.0
# ..         ...                 ...     ...                      ...     ...
# 415      95-99                  US    male                    115.0  2015.0
# 416      90-94                  US    male                    541.0  2015.0
# 417      15-19                  US  female                  10570.0  2015.0
# 418      85-89                  US    male                   1441.0  2015.0
# 419      80-84                  US    male                   2442.0  2015.0
#
# [420 rows x 5 columns]

# %%
print(country_df.shape)
country_df.head(3)
# Out:
# (10, 7)
#   country_destination  lat_destination  lng_destination  distance_km  \
# 0                  AU       -26.853388       133.275160   15297.7440
# 1                  CA        62.393303       -96.818146    2828.1333
# 2                  DE        51.165707        10.452764    7879.5680
#
#    destination_km2 destination_language   language_levenshtein_distance
# 0        7741220.0                   eng                           0.00
# 1        9984670.0                   eng                           0.00
# 2         357022.0                   deu                          72.61

# %%
session_df["action"].value_counts()[:20]
# Out:
# show                     2768278
# index                     843699
# search_results            725226
# personalize               706824
# search                    536057
# ajax_refresh_subtotal     487744
# update                    365130
# similar_listings          364624
# social_connections        339000
# reviews                   320591
# active                    188036
# similar_listings_v2       168788
# lookup                    162041
# create                    155887
# dashboard                 152952
# header_userpic            141830
# collections               124417
# edit                      109083
# campaigns                 105028
# track_page_view            81117
# Name: action, dtype: int64

# %%
session_df
# Out:
#              user_id            action action_type  \
# 0         d1mm9tcy42            lookup         NaN
# 1         d1mm9tcy42    search_results       click
# 2         d1mm9tcy42            lookup         NaN
# 3         d1mm9tcy42    search_results       click
# 4         d1mm9tcy42            lookup         NaN
# ...              ...               ...         ...
# 10567732  9uqfg8txu3         dashboard        view
# 10567733  9uqfg8txu3              edit        view
# 10567734  9uqfg8txu3     webcam_upload   -unknown-
# 10567735  9uqfg8txu3            active   -unknown-
# 10567736  9uqfg8txu3  show_personalize        data
#
#                         action_detail      device_type  secs_elapsed
# 0                                 NaN  Windows Desktop         319.0
# 1                 view_search_results  Windows Desktop       67753.0
# 2                                 NaN  Windows Desktop         301.0
# 3                 view_search_results  Windows Desktop       22141.0
# ...

# %%
session_df
# Out:
#              user_id            action action_type  \
# 0         d1mm9tcy42            lookup         NaN
# 1         d1mm9tcy42    search_results       click
# 2         d1mm9tcy42            lookup         NaN
# 3         d1mm9tcy42    search_results       click
# 4         d1mm9tcy42            lookup         NaN
# ...              ...               ...         ...
# 10567732  9uqfg8txu3         dashboard        view
# 10567733  9uqfg8txu3              edit        view
# 10567734  9uqfg8txu3     webcam_upload   -unknown-
# 10567735  9uqfg8txu3            active   -unknown-
# 10567736  9uqfg8txu3  show_personalize        data
#
#                         action_detail      device_type  secs_elapsed
# 0                                 NaN  Windows Desktop         319.0
# 1                 view_search_results  Windows Desktop       67753.0
# 2                                 NaN  Windows Desktop         301.0
# 3                 view_search_results  Windows Desktop       22141.0
# ...
