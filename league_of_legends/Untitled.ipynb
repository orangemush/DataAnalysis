# %%
import cv2

from matplotlib import pyplot as plt
import numpy as np
import time

from IPython.display import Image

# %%
img1_path = "images/abc.png"
img2_path = "images/abcd.png"

img1 = cv2.imread(img1_path, cv2.IMREAD_COLOR)
img2 = cv2.imread(img2_path)
# img2 = img[:,:,::-1]

# %%
plt.imshow(img1)

# %%
# plt.imshow(img)
plt.imshow(img1)

# %%
cv2.imshow('', img1)
# cv2.waitKey(10)
# cv2.destroyAllWindows()

# %%
# Image(image_path)

# %%
# import os

# command = """
# if test -d  /Applications/League\ of\ Legends.app/Contents/LoL/Game/ ; then cd /Applications/League\ of\ Legends.app/Contents/LoL/Game/ && chmod +x ./LeagueofLegends.app/Contents/MacOS/LeagueofLegends ; else cd /Applications/League\ of\ Legends.app/Contents/LoL/RADS/solutions/lol_game_client_sln/releases/ && cd $(ls -1vr -d */ | head -1) && cd deploy && chmod +x ./LeagueofLegends.app/Contents/MacOS/LeagueofLegends ; fi && riot_launched=true ./LeagueofLegends.app/Contents/MacOS/LeagueofLegends "spectator kr3.spectator.op.gg:80 RZTuBdx3fezaid+KtXGoEm6udaD+uUx7 5474261454 KR" "-UseRads" "-Locale=ko_KR" "-GameBaseDir=.."
# """
# os.system(command)

# %%
# img_gray = cv2.imread(image_path, cv2.IMREAD_GRAYSCALE)

# %%
blur = cv2.GaussianBlur(img_gray, ksize=(3, 3), sigmaX=0)
ret, thresh1 = cv2.threshold(blur, 127, 255, cv2.THRESH_BINARY)

# %%
plt.figure(figsize=(16, 12))
# plt.imshow(thresh1)
plt.imshow(img)

# %%
img.shape
# Out:
# (1080, 1920, 3)

# %%
plt.imshow(img[75:95, 930:1000])

# %%
import pyautogui

# %%
# command = """
# if test -d  /Applications/League\ of\ Legends.app/Contents/LoL/Game/ ; then cd /Applications/League\ of\ Legends.app/Contents/LoL/Game/ && chmod +x ./LeagueofLegends.app/Contents/MacOS/LeagueofLegends ; else cd /Applications/League\ of\ Legends.app/Contents/LoL/RADS/solutions/lol_game_client_sln/releases/ && cd $(ls -1vr -d */ | head -1) && cd deploy && chmod +x ./LeagueofLegends.app/Contents/MacOS/LeagueofLegends ; fi && riot_launched=true ./LeagueofLegends.app/Contents/MacOS/LeagueofLegends "spectator kr3.spectator.op.gg:80 RZTuBdx3fezaid+KtXGoEm6udaD+uUx7 5474261454 KR" "-UseRads" "-Locale=ko_KR" "-GameBaseDir=.."
# """
# os.system(command)

# while True:
#     print("시작")
#     time.sleep(5)
#     pyautogui.screenshot(f"images/sample.png")
#     print("성공")

# %%
pyautogui.screenshot(f"images/sample.png")

# %%
img1_path = "images/abc.png"
img2_path = "images/abcd.png"

img1 = cv2.imread(img1_path, cv2.IMREAD_COLOR)
img2 = cv2.imread(img2_path)
# img2 = img[:,:,::-1]

# %%
orb = cv2.ORB_create()
kp1, des1 = orb.detectAndCompute(img1, None)
kp2, des2 = orb.detectAndCompute(img2, None)

bf = cv2.BFMatcher(cv2.NORM_HAMMING, crossCheck=True)

matches = bf.match(des1,des2)
matches = sorted(matches, key = lambda x:x.distance)

bf = cv2.BFMatcher()

matches = bf.knnMatch(des1, des2, k=2)
good = []
for m, n in matches:
    if m.distance < 0.75 * n.distance:
        good.append([m])
    
    
plt.figure(figsize=(16, 12))
knn_image = cv2.drawMatchesKnn(img1, kp1, img2, kp2, good, None, flags=2)
plt.imshow(knn_image)
plt.show()

# %%
# matches

# %%
from selenium                 import webdriver
from webdriver_manager.chrome import ChromeDriverManager
